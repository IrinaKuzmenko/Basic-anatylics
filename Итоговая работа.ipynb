# %%
import pandas as pd

# %%
df = pd.read_sql(
"""
SELECT 
  *
FROM
  city;
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)

# %%
df.head()
# Out:
#    id            name country_code       district  population
# 0   1           Kabul          AFG          Kabol     1780000
# 1   2        Qandahar          AFG       Qandahar      237500
# 2   3           Herat          AFG          Herat      186800
# 3   4  Mazar-e-Sharif          AFG          Balkh      127800
# 4   5       Amsterdam          NLD  Noord-Holland      731200

# %%
df_vac = pd.read_csv('vacation.csv', sep=',')
df_vac.head()
# Out:
#       Отметка времени Страна отпуска Город отпуска    City EN  \
# 0   5/30/2022 9:42:59         Россия          Сочи      Sochi
# 1   5/30/2022 9:43:57         Турция       Стамбул   Istanbul
# 2   5/30/2022 9:44:38          Индия        Манали     Manali
# 3  5/30/2022 10:21:39         Швеция     Стокгольм  Stockholm
# 4  5/30/2022 10:26:09          Китай        Шанхай   Shanghai
#
#   Дата начала отпуска Дата окончания отпуска  Планируемый бюджет, руб.  \
# 0           4/16/2022              4/30/2022                  150000.0
# 1           8/11/2020              8/15/2020                   60000.0
# 2            3/6/2020              3/22/2020                  170000.0
# 3           7/16/2021              7/22/2021                  105000.0
# 4           9/19/2020              9/30/2020                  135000.0
#
#    Стоимость билетов, руб. Доля билетов в итоговых расходах  \
# 0                   9900.0                            9.18%
# ...

# %%
df_merge = df.merge(df_vac, left_on='name', right_on='City EN', how='inner')
df_merge.head()
# Out:
#      id       name country_code     district  population     Отметка времени  \
# 0   144       Baku          AZE         Baki     1787800   5/31/2022 9:08:13
# 1  1890   Shanghai          CHN     Shanghai     9696300  5/30/2022 10:26:09
# 2  3048  Stockholm          SWE       Lisboa      750348  5/30/2022 10:21:39
# 3  3357   Istanbul          TUR     Istanbul     8787958   5/30/2022 9:43:57
# 4  3520      Minsk          BLR  Horad Minsk     1674000   5/31/2022 9:03:06
#
#   Страна отпуска Город отпуска    City EN Дата начала отпуска  ...  \
# 0    Азербайджан          Баку       Baku            5/7/2021  ...
# 1          Китай        Шанхай   Shanghai           9/19/2020  ...
# 2         Швеция     Стокгольм  Stockholm           7/16/2021  ...
# 3         Турция       Стамбул   Istanbul           8/11/2020  ...
# 4     Белоруссия         Минск      Minsk            5/1/2020  ...
#
#   Стоимость отеля, руб.  Доля отеля в итоговых расходах  \
# ...

# %%
df_new = df_merge [['name', 'Страна отпуска', 'population']]
df_new
# Out:
#         name Страна отпуска  population
# 0       Baku    Азербайджан     1787800
# 1   Shanghai          Китай     9696300
# 2  Stockholm         Швеция      750348
# 3   Istanbul         Турция     8787958
# 4      Minsk     Белоруссия     1674000

# %%
df_new.groupby('Страна отпуска').mean()
# Out:
#                 population
# Страна отпуска
# Азербайджан      1787800.0
# Белоруссия       1674000.0
# Китай            9696300.0
# Турция           8787958.0
# Швеция            750348.0
